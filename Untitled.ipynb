# %%
from selenium import webdriver
from msedge.selenium_tools import EdgeOptions, Edge
import pandas as pd
import numpy as np
import time
import openpyxl
import xlwt
import os
import sys
import urllib.request
import json
import time

# %%
with open("./APISETTING.json", 'r') as f:
    json_data = json.load(f)

# %%
option = EdgeOptions()
option.use_chromium = True
option.add_argument('--headless')
option.add_argument('disable-gpu')

driver = webdriver.Chrome(
    executable_path=r'msedgedriver.exe', options=option)

driver.get("https://gamewith.jp/uma-musume/article/show/257928")
tbody = driver.find_element_by_xpath(
    "/html/body/div[6]/div/div[1]/div[1]/div[1]/div[2]/div[2]/div[3]/div/table/tbody")
trs = tbody.find_elements_by_tag_name("tr")

# %%
skilldata = []

for tr in trs:
    if tr == trs[0]:
        continue
    tds = tr.find_elements_by_tag_name("td")
    for td in tds:
        if td == tds[0]:
            continue
        temp = td.text.split("\n")
        for t in temp:
            if t == temp[1]:
                client_id = json_data["client_id"]
                client_secret = json_data["client_secret"]
                encText = urllib.parse.quote(t)
                data = "source=ja&target=en&text=" + encText
                url = "https://openapi.naver.com/v1/papago/n2mt"
                request = urllib.request.Request(url)
                request.add_header("X-Naver-Client-Id", client_id)
                request.add_header("X-Naver-Client-Secret", client_secret)
                response = urllib.request.urlopen(
                    request, data=data.encode("utf-8"))
                rescode = response.getcode()
                if(rescode != 200):
                    print("PAPAGO API ERR? -> " + rescode)
                elif(rescode == 200):
                    response_body = response.read()
                    resmess = json.loads(response_body.decode('utf-8'))
                    skilldata.append(
                        resmess['message']['result']['translatedText'])
                    print(resmess['message']['result']['translatedText'])
            if t == temp[0] :
                print(t)
                skilldata.append(t)
            time.sleep(0.11)
# Out:
# G00 1stF∞
# If you stay forward without collapsing until the last straight line, you will gain speed.
# 究極テイオーステップ
# When the difference between the front and the last straight line is closed, the speed increases a lot with splendid footwork.
# 熱血☆アミーゴ
# It's easier to have a slight advantage when you're in front of the line with extra strength.
# アタシもたまには、ね？
# If you are about to lose in third place at the end of the race, your fighting spirit will be ignited and your speed will rise a little.
# 勝利のキッス☆
# If you compete in the front in the final corner, you will be able to get out slightly in the straight line.
# 不沈艦、抜錨ォッ！
# speed up little by little from the middle of the race with a long spurt
# 先頭の景色は譲らない…！
# Increase the speed by using more legs when you are ahead in the final straight line.
# 汝、皇帝の神威を見よ
# If you pass three times at the end of the race, your speed will increase a lot in the final straight line.
# 勝利のチケットを、君にッ！
# I feel like I won't lose the competition in the final straight line, and the speed increases.
# 最強の名をかけて
# The speed will increase if you are exhausted in the front after the last corner.
# ブレイズ・オブ・プライド
# If you overtake from behind in the last corner, you will speed up with the empress running.
# ブルーローズチェイサー
# The speed increases with a strong will when you get out of the final straight line.
# Call me KING
# If you can carry the race calmly, you will demonstrate your ability and speed up with 200m left.
# レッドエース
# show a slight ability to keep first place in the second half of the race
# 全力Vサインッ！
# I feel like I won't lose the competition in the final straight line, and the speed increases a little.
# 優等生×バクシン=大勝利ッ
# In the second half of the race, if you compete in the front, you will show your strength and speed up.
# Pride of KING
# If you can carry the race calmly, you will demonstrate your ability with 200m left, and your speed will increase a lot.
# プランチャ☆ガナドール
# It's easier to have an advantage when you're in front of the line with extra strength.
# ひらめき☆ランディング
# If you compete in the front at the last corner, it will be easy to get out in a straight line.
# 貴顕の使命を果たすべく
# If you are in the front in the final corner, you will be prepared not to let it get out of the way and speed up.
# 来ます来てます来させます！
# clear the way with the power of a sign that the front is clogged at the end of the race
# カッティング×DRIVE！
# If you are less than 200m away, the competition will become stronger and the speed will increase.
# ヴィクトリーショット！
# If you are in a good position in the last corner, you will gain momentum and accelerate.
# エンプレス・プライド
# If you overtake from behind in the last corner, you'll get a little faster with the empress running.
# 学級委員長＋速さ＝バクシン
# In the second half of the race, if you compete in the front, you will show your strength and speed up a little.
# 来てください来てください！
# cut a little way with the power of an announcement that the front is clogged at the end of the race
# LookatCurren
# When you are in a good position near the middle of the race, you can overtake and start advancing vigorously.
# ヴィットーリアに捧ぐ舞踏
# If you compete in the front at the last corner, you will speed up with the king's brilliance.
# ブリリアント・レッドエース
# show one's ability to keep first place in the second half of the race
# きっとその先へ…！
# If you are about to lose in third place at the end of the race, your fighting spirit will be ignited and your speed will increase.
# レッツ・アナボリック！
# Acceleration increases in the last corner of the race trying to get to the front position.
# 波乱注意砲！
# speed up slightly from the middle of the race with a long spurt
# 精神一到何事か成らざらん
# If you overtake from the back on the final straight line, you will increase the speed by using the last legs.
# 勝利の鼓動
# With 200m left, if you're in front of you, you'll be able to get out of the way.
# 燃えろ筋肉！
# The acceleration increases a little in the last corner of the race trying to get to the front position.
# win Q.E.D
# Leading ahead in the final corner leads to victory equation and speeds up.
# アクセルX
# If you are less than 200m away, the competition will become stronger and the speed will increase a little.
# 絶対は、ボクだ
# If you are chasing forward in the final straight line, you will speed up with unyielding fighting spirit.
# シューティングスター
# If you overtake your opponent in the front at the end of the race, you'll gain momentum and speed up.
# 精神一到
# If you overtake from the back on the final straight line, the speed will increase a little using the last leg.
# 紅焔ギア/LP1211-M
# If you are in the front after the last corner, the acceleration increases by changing gears.
# 注目の踊り子
# get better at taking the course at the beginning of the race
# 圧倒的リード
# It's easy to maintain a lead in the middle of the race.
# ライトニングステップ
# In the middle of the race, if you're behind you, you won't be surrounded easily <medium distance>
# レーンの魔術師
# get better at taking the course late in the race
# 弧線のプロフェッサー
# get better at corners and speed up
# スピードスター
# It will be easier to get out of the final corner <Plot, advance>
# スプリントターボ
# The acceleration force increases in a straight line <short distance>
# 先陣の心得
# It's easy to maintain a lead in the middle of the race.
# 視界良好！異常なし！
# Move left and right to grasp the situation and broaden your horizons a little.
# 大局観
# In the middle of the race, your observation will increase and you will be able to have a wider field of vision.
# ハヤテ一文字
# speed up in a straight line
# 逃亡者
# It will be easier to keep the lead in the final corner <Operation, Escape>
# マイルの支配者
# It will be easier to widen the gap if you take the lead at the beginning of the race <miles>
# 決意の直滑降
# Get a little better at downhill <Plot, advance>
# キラーチューン
# In the middle of the race, it's easier to get a good position in the front.
# 勝利への執念
# If you are overtaken at the last corner, it will be easier to return <medium distance>
# 努力家
# It will be easier to overtake successfully <Plot, Insert>
# コンセントレーション
# get off to a better start and slightly less time to start
# 昇り龍
# Speed increases when overtaking from the outside in the final corner <Operation, Insertion>
# ノンストップガール
# When the front is blocked at the end of the spurt, you will be able to act well.
# 先手必勝
# It will be easier to get to the front at the beginning of the race <Operation, Escape>
# 迅速果断
# Speeds up in the middle of the race <Plot, Insert>
# プランX
# It's easier to pull out if you're in the middle of the race.
# 乗り換え上手
# Acceleration increases at the end of the race <Operation, Insertion>
# 技巧派
# Course taking will be a little smoother <Operation, Advance>
# 曲線のソムリエ
# Gorgeous cornerwork increases acceleration
# アクセル全開！
# Acceleration increases when overtaking in the middle of the race <mile
# 電撃の煌めき
# At the end of the race, it will be easier to spurt in the back.
# 全身全霊
# speed up in the last spurt
# 脱出術
# In the middle of the race, it will be easier to get to the front <Operation, Escape>
# ギアチェンジ
# If you are in the front in the middle of the race, it will be easier to pull out.
# 豪脚
# At the end of the race, the ability to overtake increases <miles> from the back.
# 一陣の風
# The acceleration power increases in a straight line.
# 千里眼
# At the beginning of the race, your observation will increase and you will be able to have a wide field of vision.
# 詰め寄り
# At the end of the race, it will be slightly easier to spurt in the back.
# アクセラレーション
# Acceleration increases slightly when overtaking in the middle of the race <miles>
# 追込コーナー◯
# The speed increases slightly in the corner <Operation, pursuit>
# 差し直線◯
# The speed increases slightly in a straight line <Operation, Insertion>
# 遊びはおしまいっ！
# If the horse girl is right behind you for a long time, you'll get a little faster.
# 差しコーナー◯
# The speed increases slightly in the corner <Plot, Insert>
# 策士
# If you are behind at the end of the race, your field of vision becomes slightly wider <Operation, pursuit>
# コーナー加速◯
# Gorgeous cornerwork slightly increases acceleration
# ポジションセンス
# get a little better in the early stages of the race
# 集中力
# get off to a better start and slightly less time to start
# 直線一気
# The acceleration force increases slightly in the straight line of the last spurt <Operation, pursuit>
# 追い上げ
# Speed increases slightly when overtaking at the end of the race <long distance>
# 逃げコーナー◯
# The speed increases slightly in the corner <Operation, Escape>
# がんばり屋
# Slightly easier to succeed in overtaking <Operation, Insertion>
# 長距離直線◯
# Speed increases slightly in a straight line <long distance>
# 登山家
# get a little better at uphill
# 大きなリード
# It's easy to maintain a slight lead in the middle of the race.
# 積極策
# It will be easier to widen the gap slightly if you take the lead at the beginning of the race <mile
# 長距離コーナー◯
# The speed increases slightly in the corner <long distance>
# 地固め
# If you exercise a lot of skills at the beginning of the race, your acceleration will increase slightly.
# 急ぎ足
# In the middle of the race, it becomes slightly easier to go forward <Operation, Escape>
# 食い下がり
# If overtaken in the final corner, it is slightly easier to replace <medium distance>
# 外差し準備
# If you overtake from the outside in the final corner, the speed will increase slightly <Operation, Insertion>
# 臨機応変
# get a little better at the end of the race
# 先行直線◯
# The speed increases slightly in a straight line <Operation, Advance>
# 上昇気流
# At the end of the race, the ability to overtake from behind increases slightly <miles>
# 抜け出し準備
# It will be slightly easier to get out of the final corner <Operation, Advance>
# 読解力
# In the middle of the race, the ability to observe increases and the field of vision is slightly wider.
# 内弁慶
# The speed increases slightly when you're on the inner side of the final corner <long distance>
# 善後策
# In the middle of the race, if you are in the front, it will be a little easier to pull out. <short distance>
# ギアシフト
# If you are in the front in the middle of the race, it will be slightly easier to pull out.
# 仕掛け抜群
# Towards the end of the race, we are ready to drive and slightly raise our position.
# リードキープ
# It's easy to maintain a slight lead in the middle of the race.
# 十万バリキ
# The speed increases slightly on the uphill <Operation, Insertion>
# 中距離コーナー◯
# The speed increases slightly at the corner <medium distance>
# イナズマステップ
# If you're in the back in the middle of the race, it's a little harder to get surrounded <Medium distance>
# マイル直線◯
# Speed increases slightly in a straight line <miles>
# 尻尾上がり
# If you exercise a lot of skills in the middle of the race, the speed will increase slightly.
# 逃げ直線◯
# The speed increases slightly in a straight line <Operation, Escape>
# ペースアップ
# speed up slightly in the middle of the race
# 中距離直線◯
# Speed increases slightly in a straight line <medium distance>
# 先行コーナー◯
# The speed increases slightly at the corner <Operation, Advance>
# お見通し
# Move left and right to grasp the situation and slightly broaden your field of view <Operation, pursuit>
# スプリントギア
# The acceleration force increases slightly in a straight line <short distance>
# 先駆け
# It becomes slightly easier to get to the front in the beginning of the race <Operation, Escape>
# 末脚
# pick up speed slightly in the last spurt
# ホークアイ
# At the beginning of the race, my observation will increase and I can have a slightly wider view <medium distance>
# テンポアップ
# In the middle of the race, it's slightly easier to get a good position in the front.
# まき直し
# Acceleration increases slightly when you are in the back in the middle of the race <Operation, Advance>
# 仕掛け準備
# Prepare a little for the finish line in the middle of the race <short distance>
# 追込直線◯
# The speed increases slightly in a straight line <Operation/Pursuit>
# 直線加速
# The acceleration power increases slightly in a straight line.
# 垂れウマ回避
# get a little better when the front is blocked at the end of one's spurt
# 位置取り押し上げ
# The speed increases slightly in the middle of the race <Operation, Insertion>
# 直線巧者
# speed up slightly in a straight line
# 直滑降
# Slightly good at downhill <Plot, advance>
# 差し切り体勢
# Acceleration increases slightly at the end of the race <Operation, Insertion>
# 二の矢
# Acceleration increases slightly when you are behind in the middle of the race <Operation, Escape>
# 負けん気
# Slightly easier to overtake <miles>
# 短距離直線◯
# The speed increases slightly in a straight line <short distance>
# 押し切り準備
# It will be easier to keep the lead slightly in the final corner <Operation, Escape>
# コーナー巧者◯
# get better at the corner and speed up slightly
# マイルコーナー◯
# The speed increases slightly in the corner <miles>
# ウマ好み
# If there are many horse girls nearby, the speed will increase slightly.
# 危険回避
# <Operation, escape> It will be a little difficult to be surrounded in the beginning of the race.
# 巧みなステップ
# <Plot, advance> The course will be slightly smoother
# 先頭プライド
# <Operation, escape> It becomes slightly harder to overtake at the beginning of the race.
# スリップストリーム
# If you put it right behind the horse girl in front of you, you won't be able to resist the wind.
# 短距離コーナー◯
# 対抗意識◯
# If there are more than six horsedaughters who have the same strategy as me, it is easier to show their ability.
# 内枠得意◯
# I will be a little better at races with 1-3 frame numbers.
# 冬ウマ娘◯
# get a little better at winter races
# 逃げのコツ◯
# It will be easier to get to a good position <Plot, escape>
# 外枠得意◯
# I'll be a little better at races with 6-8 frames.
# 道悪◯
# "After a while, I will be a little better at ""heavy"" and ""bad""."
# 曇りの日◯
# get a little better at racing on a cloudy day
# 春ウマ娘◯
# get a little better at spring races
# 京都レース場◯
# get a little better at Kyoto Racecourse
# 左回り◯
# get a little better at the counterclockwise course
# 雨の日◯
# get a little better at racing on rainy days
# 函館レース場◯
# I get a little better at Hakodate Racecourse.
# シンパシー
# If there are many horse girls with sympathetic hearts, their abilities will improve a little.
# おひとり様◯
# It's easy to show your ability without a horse girl who has the same strategy as you.
# 夏ウマ娘◯
# get a little better at summer races
# ラッキーセブン
# Sometimes good things happen when the frame number is 7.
# 晴れの日◯
# get a little better at racing on a sunny day
# 雪の日◯
# get a little better at racing on a snowy day
# 札幌レース場◯
# get a little better at Sapporo Racecourse
# 先行のコツ◯
# It will be easier to get to a good position <plot, advance>
# 徹底マーク◯
# It's easier to show your ability if you have the same strategy as the most popular horse girl.
# 大井レース場◯
# I get a little better at Oi Racecourse
# 伏兵◯
# It is easy to show a little ability in the race below the 4th most popular.
# 根幹距離◯
# Become a little better at root distance (multiple of 400m)
# 阪神レース場◯
# get a little better at Hanshin Racecourse
# 秋ウマ娘◯
# get a little better at the autumn race
# 東京レース場◯
# get a little better at Tokyo Racecourse
# 追込のコツ◯
# <Operation, pursuit> It will be easier to get to a good position.
# 差しのコツ◯
# It will be easier to get to a good position <Plot, Insert>
# 右回り◯
# get a little better at the right-hand course
# 一匹狼
# In a race where you are the only one who has a loner heart, your ability improves a little.
# 非根幹距離◯
# Become a little better at non-root distances (other than multiples of 400m)
# 中山レース場◯
# get a little better at Nakayama Racecourse
# 小倉レース場◯
# get a little better at Ogura Racecourse

# %%
npData = np.array(skilldata)

# %%
npDataReshaped = npData.reshape(int(len(skilldata) / 2), 2)

# %%
df = pd.DataFrame(npDataReshaped, columns=["skillName", "skillInfo"])
df.to_excel("./skill_spec_en.xls")
print("************************")
print("skill crawling finished!")
print("************************")
# Out:
# ************************
# skill crawling finished!
# ************************
# <ipython-input-14-b0b3fd957fff>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("./skill_spec_en.xls")

# %%
npData = np.array(skilldata)
npDataReshaped = npData.reshape(int(len(skilldata) / 2), 2)

df = pd.DataFrame(npDataReshaped, columns=["skillName", "skillInfo"])
df.to_excel("./skill_spec_en.xls")
print("************************")
print("skill crawling finished!")
print("************************")
